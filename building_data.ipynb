# %% [markdown]
# This is a notebook showing how the final data used for data analysis and hypothesis testing is build from all the available data files stored in eye_data and input_data respectively.

# %%
import os
import math
import numpy as np
import pandas as pd
from ast import literal_eval
import itertools
import arviz as az
import scipy.stats as st
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.patches as  mpatches
pd.options.mode.chained_assignment = None  # default='warn'

from helper_functions import *

agent_center_x = 972
agent_center_y = 288

# %% [markdown]
# We first identify all data files that belong to a successfull play-through of a trial (indicated by done string in file name). We only take successfull runs for better comparability.

# %%
root_dir = os.getcwd()

data_dir = "/experimental_data/"

target_string = "output"
target_string_eye_tracking = "eye_tracking"
done_string = "done"

successfull_runs = []

for subdir, dirs, files in os.walk(root_dir+data_dir):
    for file in files:
        if done_string in file:
            successfull_runs.append(file)

# all data files have in their names a triplet for identification...       
# triplet coding: level, drift (True vs. False), input noise (None vs. Weak vs. Strong)

# %%
successfull_runs
# Out:
# ['OK01UE_output_5FN_done_10.csv',
#  'OK01UE_output_3FN_done_25.csv',
#  'OK01UE_output_6FN_done_16.csv',
#  'OK01UE_output_2FS_done_27.csv',
#  'OK01UE_output_4FS_done_07.csv',
#  'OK01UE_output_4FW_done_36.csv',
#  'OK01UE_output_3TS_done_14.csv',
#  'OK01UE_output_1FW_done_06.csv',
#  'OK01UE_output_6FW_done_02.csv',
#  'OK01UE_output_5FS_done_40.csv',
#  'OK01UE_output_4TN_done_21.csv',
#  'OK01UE_output_1TS_done_32.csv',
#  'OK01UE_output_0TS_done_00.csv',
#  'OK01UE_output_3FW_done_22.csv',
#  'OK01UE_output_3TN_done_00.csv',
#  'OK01UE_output_1FN_done_47.csv',
#  'OK01UE_output_6TW_done_50.csv',
#  'OK01UE_output_5FW_done_30.csv',
#  'OK01UE_output_2TS_done_39.csv',
#  'OK01UE_output_2FN_done_41.csv',
#  'OK01UE_output_5TS_done_15.csv',
#  'OK01UE_output_2TN_done_20.csv',
#  'OK01UE_output_1FS_done_48.csv',
#  'OK01UE_output_2FW_done_18.csv',
#  'OK01UE_output_1TN_done_33.csv',
#  'OK01UE_output_3TW_done_28.csv',
#  'OK01UE_output_2TW_done_31.csv',
#  'OK01UE_output_4TW_done_13.csv',
#  'OK01UE_output_3FS_done_19.csv',
#  'OK01UE_output_4FN_done_11.csv',
#  'OK01UE_output_1TW_done_24.csv',
#  'OK01UE_output_6FS_done_04.csv',
#  'EU29TT1_output_1TS_done_21.csv',
#  'EU29TT1_output_1TN_done_29.csv',
#  'EU29TT1_output_2TS_done_24.csv',
#  'EU29TT1_output_1FW_done_12.csv',
#  'EU29TT1_output_4TW_done_51.csv',
#  'EU29TT1_output_0TS_done_00.csv',
#  'EU29TT1_output_3TW_done_50.csv',
#  'EU29TT1_output_3TN_done_41.csv',
#  'EU29TT1_output_1TW_done_15.csv',
#  'EU29TT1_output_2TW_done_13.csv',
#  'EU29TT1_output_4FW_done_40.csv',
#  'EU29TT1_output_1FN_done_10.csv',
#  'EU29TT1_output_1FS_done_18.csv',
#  'EU29TT1_output_4FN_done_33.csv',
#  'EU29TT1_output_4FS_done_39.csv',
#  'EU29TT1_output_6FS_done_17.csv',
#  'EU29TT1_output_3FS_done_19.csv',
#  'EU29TT1_output_6TN_done_45.csv',
#  'EU29TT1_output_2FS_done_14.csv',
#  'EU29TT1_output_2FN_done_08.csv',
#  'EU29TT1_output_3FN_done_16.csv',
#  'EU29TT1_output_6FW_done_46.csv',
#  'EU29TT1_output_5FS_done_00.csv',
#  'EU29TT1_output_5FW_done_42.csv',
#  'EU29TT1_output_5FN_done_35.csv',
#  'EU29TT1_output_2FW_done_52.csv',
#  'EU29TT1_output_6FN_done_26.csv',
#  'EU29TT1_output_3FW_done_38.csv',
#  'EU29TT1_output_4TS_done_34.csv',
#  'EU29TT1_output_3TS_done_30.csv',
#  'EU29TT1_output_4TN_done_03.csv',
#  'EU29TT1_output_2TN_done_09.csv',
#  'AM19EA1_output_5FS_done_26.csv',
#  'AM19EA1_output_3FW_done_53.csv',
#  'AM19EA1_output_1TW_done_17.csv',
#  'AM19EA1_output_2FN_done_00.csv',
#  'AM19EA1_output_1FN_done_11.csv',
#  'AM19EA1_output_6FN_done_12.csv',
#  'AM19EA1_output_4TW_done_23.csv',
#  'AM19EA1_output_4FS_done_10.csv',
#  'AM19EA1_output_4FW_done_20.csv',
#  'AM19EA1_output_2TN_done_05.csv',
#  'AM19EA1_output_3TS_done_01.csv',
#  'AM19EA1_output_6FS_done_52.csv',
#  'AM19EA1_output_0TS_done_00.csv',
#  'AM19EA1_output_3TW_done_46.csv',
#  'AM19EA1_output_2FW_done_04.csv',
#  'AM19EA1_output_6FW_done_38.csv',
#  'AM19EA1_output_1TS_done_25.csv',
#  'AM19EA1_output_2TS_done_39.csv',
#  'AM19EA1_output_1FW_done_24.csv',
#  'AM19EA1_output_5TN_done_19.csv',
#  'AM19EA1_output_1TN_done_18.csv',
#  'AM19EA1_output_3TN_done_07.csv',
#  'AM19EA1_output_5FN_done_40.csv',
#  'AM19EA1_output_4TS_done_36.csv',
#  'AM19EA1_output_4TN_done_02.csv',
#  'AM19EA1_output_3FS_done_31.csv',
#  'AM19EA1_output_2FS_done_29.csv',
#  'AM19EA1_output_1FS_done_14.csv',
#  'AM19EA1_output_2TW_done_37.csv',
#  'AM19EA1_output_4FN_done_06.csv',
#  'AM19EA1_output_3FN_done_28.csv',
#  'AS01RH1_output_6TW_done_27.csv',
#  'AS01RH1_output_3TW_done_28.csv',
#  'AS01RH1_output_2FW_done_42.csv',
#  'AS01RH1_output_5FN_done_18.csv',
#  'AS01RH1_output_6FS_done_06.csv',
#  'AS01RH1_output_2TW_done_09.csv',
#  'AS01RH1_output_5FS_done_02.csv',
#  'AS01RH1_output_5FW_done_43.csv',
#  'AS01RH1_output_4FS_done_26.csv',
#  'AS01RH1_output_3FN_done_17.csv',
#  'AS01RH1_output_3FW_done_07.csv',
#  'AS01RH1_output_1TN_done_37.csv',
#  'AS01RH1_output_6FW_done_23.csv',
#  'AS01RH1_output_2TN_done_35.csv',
#  'AS01RH1_output_2TS_done_29.csv',
#  'AS01RH1_output_5TN_done_31.csv',
#  'AS01RH1_output_4FW_done_38.csv',
#  'AS01RH1_output_1FW_done_12.csv',
#  'AS01RH1_output_2FS_done_40.csv',
#  'AS01RH1_output_1TS_done_25.csv',
#  'AS01RH1_output_4TN_done_36.csv',
#  'AS01RH1_output_0TS_done_00.csv',
#  'AS01RH1_output_3TN_done_19.csv',
#  'AS01RH1_output_3TS_done_05.csv',
#  'AS01RH1_output_6FN_done_01.csv',
#  'AS01RH1_output_1FN_done_10.csv',
#  'AS01RH1_output_4TW_done_30.csv',
#  'AS01RH1_output_4FN_done_21.csv',
#  'AS01RH1_output_1TW_done_00.csv',
#  'AS01RH1_output_5TS_done_46.csv',
#  'AS01RH1_output_3FS_done_14.csv',
#  'AS01RH1_output_2FN_done_11.csv',
#  'AS01RH1_output_1FS_done_08.csv',
#  'AN10HA1_output_5TN_done_04.csv',
#  'AN10HA1_output_4TW_done_54.csv',
#  'AN10HA1_output_0TS_done_00.csv',
#  'AN10HA1_output_2TN_done_03.csv',
#  'AN10HA1_output_2FS_done_42.csv',
#  'AN10HA1_output_4TN_done_18.csv',
#  'AN10HA1_output_1TN_done_28.csv',
#  'AN10HA1_output_3TN_done_37.csv',
#  'AN10HA1_output_6FS_done_40.csv',
#  'AN10HA1_output_4FW_done_34.csv',
#  'AN10HA1_output_5FW_done_13.csv',
#  'AN10HA1_output_3TW_done_26.csv',
#  'AN10HA1_output_2TW_done_15.csv',
#  'AN10HA1_output_3FS_done_02.csv',
#  'AN10HA1_output_6FN_done_38.csv',
#  'AN10HA1_output_4FN_done_08.csv',
#  'AN10HA1_output_5FS_done_32.csv',
#  'AN10HA1_output_5TW_done_29.csv',
#  'AN10HA1_output_1TW_done_01.csv',
#  'AN10HA1_output_3FN_done_14.csv',
#  'AN10HA1_output_2TS_done_49.csv',
#  'AN10HA1_output_1FS_done_05.csv',
#  'AN10HA1_output_4FS_done_22.csv',
#  'AN10HA1_output_3TS_done_43.csv',
#  'AN10HA1_output_5FN_done_33.csv',
#  'AN10HA1_output_2FN_done_36.csv',
#  'AN10HA1_output_2FW_done_31.csv',
#  'AN10HA1_output_1FW_done_09.csv',
#  'AN10HA1_output_1TS_done_12.csv',
#  'AN10HA1_output_1FN_done_52.csv',
#  'AN10HA1_output_6FW_done_20.csv',
#  'AN10HA1_output_3FW_done_39.csv',
#  'LJ28VA1_output_5FW_done_13.csv',
#  'LJ28VA1_output_6FN_done_61.csv',
#  'LJ28VA1_output_4FW_done_22.csv',
#  'LJ28VA1_output_0TS_done_00.csv',
#  'LJ28VA1_output_2TS_done_21.csv',
#  'LJ28VA1_output_3TN_done_43.csv',
#  'LJ28VA1_output_4TN_done_56.csv',
#  'LJ28VA1_output_3FN_done_35.csv',
#  'LJ28VA1_output_3FS_done_00.csv',
#  'LJ28VA1_output_2FN_done_06.csv',
#  'LJ28VA1_output_4TW_done_37.csv',
#  'LJ28VA1_output_2TW_done_18.csv',
#  'LJ28VA1_output_3TW_done_03.csv',
#  'LJ28VA1_output_1TW_done_08.csv',
#  'LJ28VA1_output_1FS_done_14.csv',
#  'LJ28VA1_output_1TS_done_58.csv',
#  'LJ28VA1_output_2FS_done_10.csv',
#  'LJ28VA1_output_5FN_done_36.csv',
#  'LJ28VA1_output_4FN_done_05.csv',
#  'LJ28VA1_output_1TN_done_34.csv',
#  'LJ28VA1_output_6FS_done_60.csv',
#  'LJ28VA1_output_2TN_done_27.csv',
#  'LJ28VA1_output_1FW_done_25.csv',
#  'LJ28VA1_output_3FW_done_12.csv',
#  'LJ28VA1_output_1FN_done_42.csv',
#  'LJ28VA1_output_3TS_done_31.csv',
#  'LJ28VA1_output_4FS_done_51.csv',
#  'LJ28VA1_output_2FW_done_33.csv',
#  'LJ28VA1_output_5TW_done_47.csv',
#  'OC19AS1_output_6FS_done_23.csv',
#  'OC19AS1_output_2TW_done_10.csv',
#  'OC19AS1_output_3FS_done_07.csv',
#  'OC19AS1_output_6FN_done_01.csv',
#  'OC19AS1_output_5TN_done_48.csv',
#  'OC19AS1_output_4TW_done_09.csv',
#  'OC19AS1_output_2FS_done_18.csv',
#  'OC19AS1_output_1FS_done_34.csv',
#  'OC19AS1_output_3TW_done_32.csv',
#  'OC19AS1_output_3FN_done_35.csv',
#  'OC19AS1_output_2FW_done_00.csv',
#  'OC19AS1_output_4FS_done_49.csv',
#  'OC19AS1_output_6FW_done_05.csv',
#  'OC19AS1_output_4FW_done_26.csv',
#  'OC19AS1_output_0TS_done_00.csv',
#  'OC19AS1_output_2TN_done_14.csv',
#  'OC19AS1_output_1TS_done_30.csv',
#  'OC19AS1_output_5TW_done_43.csv',
#  'OC19AS1_output_2TS_done_04.csv',
#  'OC19AS1_output_3TN_done_03.csv',
#  'OC19AS1_output_3TS_done_20.csv',
#  'OC19AS1_output_4TS_done_08.csv',
#  'OC19AS1_output_3FW_done_17.csv',
#  'OC19AS1_output_4TN_done_15.csv',
#  'OC19AS1_output_1FN_done_41.csv',
#  'OC19AS1_output_1TN_done_31.csv',
#  'OC19AS1_output_5FW_done_45.csv',
#  'OC19AS1_output_4FN_done_02.csv',
#  'OC19AS1_output_2FN_done_21.csv',
#  'OC19AS1_output_5FN_done_19.csv',
#  'OC19AS1_output_1TW_done_27.csv',
#  'OC19AS1_output_1FW_done_40.csv',
#  'AG11ER1_output_1FN_done_22.csv',
#  'AG11ER1_output_3FN_done_01.csv',
#  'AG11ER1_output_5FW_done_40.csv',
#  'AG11ER1_output_4FS_done_18.csv',
#  'AG11ER1_output_3TS_done_44.csv',
#  'AG11ER1_output_3TW_done_05.csv',
#  'AG11ER1_output_4FN_done_13.csv',
#  'AG11ER1_output_5FN_done_35.csv',
#  'AG11ER1_output_5TW_done_37.csv',
#  'AG11ER1_output_2FS_done_14.csv',
#  'AG11ER1_output_4TS_done_50.csv',
#  'AG11ER1_output_6TN_done_47.csv',
#  'AG11ER1_output_6FS_done_16.csv',
#  'AG11ER1_output_3FS_done_25.csv',
#  'AG11ER1_output_1TN_done_42.csv',
#  'AG11ER1_output_2TN_done_20.csv',
#  'AG11ER1_output_4FW_done_39.csv',
#  'AG11ER1_output_6FW_done_19.csv',
#  'AG11ER1_output_3TN_done_00.csv',
#  'AG11ER1_output_1TS_done_28.csv',
#  'AG11ER1_output_1FW_done_27.csv',
#  'AG11ER1_output_5TN_done_34.csv',
#  'AG11ER1_output_2TS_done_38.csv',
#  'AG11ER1_output_5TS_done_30.csv',
#  'AG11ER1_output_3FW_done_09.csv',
#  'AG11ER1_output_0TS_done_00.csv',
#  'AG11ER1_output_2FW_done_10.csv',
#  'AG11ER1_output_4TN_done_26.csv',
#  'AG11ER1_output_4TW_done_23.csv',
#  'AG11ER1_output_1FS_done_21.csv',
#  'AG11ER1_output_5FS_done_31.csv',
#  'AG11ER1_output_2FN_done_15.csv',
#  'AG11ER1_output_1TW_done_03.csv',
#  'AG11ER1_output_6FN_done_02.csv',
#  'AG11ER1_output_2TW_done_11.csv',
#  'EI13RE1_output_6FN_done_10.csv',
#  'EI13RE1_output_2TW_done_17.csv',
#  'EI13RE1_output_4FS_done_06.csv',
#  'EI13RE1_output_2FS_done_33.csv',
#  'EI13RE1_output_2FN_done_13.csv',
#  'EI13RE1_output_6FS_done_55.csv',
#  'EI13RE1_output_4FW_done_37.csv',
#  'EI13RE1_output_4TN_done_30.csv',
#  'EI13RE1_output_5FW_done_29.csv',
#  'EI13RE1_output_0TS_done_00.csv',
#  'EI13RE1_output_1FW_done_03.csv',
#  'EI13RE1_output_2TS_done_34.csv',
#  'EI13RE1_output_1TS_done_14.csv',
#  'EI13RE1_output_1TN_done_09.csv',
#  'EI13RE1_output_3TW_done_49.csv',
#  'EI13RE1_output_5FN_done_50.csv',
#  'EI13RE1_output_3FW_done_07.csv',
#  'EI13RE1_output_2FW_done_18.csv',
#  'EI13RE1_output_3TN_done_04.csv',
#  'EI13RE1_output_2TN_done_36.csv',
#  'EI13RE1_output_1TW_done_53.csv',
#  'EI13RE1_output_4TW_done_12.csv',
#  'EI13RE1_output_3TS_done_57.csv',
#  'EI13RE1_output_1FS_done_05.csv',
#  'EI13RE1_output_3FN_done_00.csv',
#  'EI13RE1_output_3FS_done_20.csv',
#  'EI13RE1_output_1FN_done_23.csv',
#  'IT02IT1_output_4FS_done_18.csv',
#  'IT02IT1_output_1FS_done_13.csv',
#  'IT02IT1_output_2FS_done_16.csv',
#  'IT02IT1_output_3FN_done_39.csv',
#  'IT02IT1_output_2TW_done_30.csv',
#  'IT02IT1_output_2FN_done_20.csv',
#  'IT02IT1_output_1FN_done_19.csv',
#  'IT02IT1_output_4TS_done_34.csv',
#  'IT02IT1_output_5FS_done_48.csv',
#  'IT02IT1_output_5FW_done_36.csv',
#  'IT02IT1_output_3TN_done_07.csv',
#  'IT02IT1_output_1TS_done_10.csv',
#  'IT02IT1_output_2TS_done_06.csv',
#  'IT02IT1_output_5TN_done_37.csv',
#  'IT02IT1_output_3TS_done_21.csv',
#  'IT02IT1_output_0TS_done_00.csv',
#  'IT02IT1_output_2TN_done_15.csv',
#  'IT02IT1_output_1TN_done_29.csv',
#  'IT02IT1_output_1FW_done_12.csv',
#  'IT02IT1_output_2FW_done_02.csv',
#  'IT02IT1_output_6TS_done_33.csv',
#  'IT02IT1_output_5TS_done_50.csv',
#  'IT02IT1_output_3TW_done_27.csv',
#  'IT02IT1_output_3FW_done_43.csv',
#  'IT02IT1_output_4FN_done_25.csv',
#  'IT02IT1_output_3FS_done_11.csv',
#  'IT02IT1_output_6FW_done_49.csv',
#  'IT02IT1_output_6FN_done_03.csv',
#  'IT02IT1_output_1TW_done_28.csv',
#  'IT02IT1_output_4TN_done_46.csv',
#  'IT02IT1_output_4FW_done_41.csv',
#  'IT02IT1_output_4TW_done_24.csv',
#  'IT02IT1_output_5FN_done_05.csv',
#  'AR02AA_output_2TN_done_20.csv',
#  'AR02AA_output_2FW_done_25.csv',
#  'AR02AA_output_1FW_done_21.csv',
#  'AR02AA_output_6FW_done_09.csv',
#  'AR02AA_output_3TN_done_28.csv',
#  'AR02AA_output_6FS_done_49.csv',
#  'AR02AA_output_5FW_done_33.csv',
#  'AR02AA_output_1TS_done_15.csv',
#  'AR02AA_output_2TS_done_38.csv',
#  'AR02AA_output_3TW_done_13.csv',
#  'AR02AA_output_3FS_done_08.csv',
#  'AR02AA_output_5FN_done_37.csv',
#  'AR02AA_output_6FN_done_18.csv',
#  'AR02AA_output_2FS_done_10.csv',
#  'AR02AA_output_4TW_done_29.csv',
#  'AR02AA_output_4FW_done_46.csv',
#  'AR02AA_output_1FS_done_23.csv',
#  'AR02AA_output_1FN_done_01.csv',
#  'AR02AA_output_3FW_done_41.csv',
#  'AR02AA_output_3FN_done_27.csv',
#  'AR02AA_output_1TW_done_16.csv',
#  'AR02AA_output_4FS_done_14.csv',
#  'AR02AA_output_2TW_done_05.csv',
#  'AR02AA_output_2FN_done_17.csv',
#  'AR02AA_output_4TN_done_36.csv',
#  'AR02AA_output_3TS_done_07.csv',
#  'AR02AA_output_5FS_done_43.csv',
#  'AR02AA_output_4FN_done_51.csv',
#  'AR02AA_output_0TS_done_00.csv',
#  'AR02AA_output_5TS_done_22.csv',
#  'AR02AA_output_1TN_done_00.csv',
#  'ON27IN1_output_1TS_done_15.csv',
#  'ON27IN1_output_5TN_done_35.csv',
#  'ON27IN1_output_6FW_done_23.csv',
#  'ON27IN1_output_3FW_done_10.csv',
#  'ON27IN1_output_2FW_done_20.csv',
#  'ON27IN1_output_3FS_done_41.csv',
#  'ON27IN1_output_5TW_done_47.csv',
#  'ON27IN1_output_3TN_done_06.csv',
#  'ON27IN1_output_3TS_done_26.csv',
#  'ON27IN1_output_2TW_done_30.csv',
#  'ON27IN1_output_6FS_done_16.csv',
#  'ON27IN1_output_4TS_done_44.csv',
#  'ON27IN1_output_4FS_done_08.csv',
#  'ON27IN1_output_1FS_done_07.csv',
#  'ON27IN1_output_2FN_done_34.csv',
#  'ON27IN1_output_3TW_done_29.csv',
#  'ON27IN1_output_6TN_done_45.csv',
#  'ON27IN1_output_3FN_done_14.csv',
#  'ON27IN1_output_6FN_done_33.csv',
#  'ON27IN1_output_4FN_done_21.csv',
#  'ON27IN1_output_5FN_done_04.csv',
#  'ON27IN1_output_4TW_done_31.csv',
#  'ON27IN1_output_2FS_done_18.csv',
#  'ON27IN1_output_4TN_done_43.csv',
#  'ON27IN1_output_1TW_done_05.csv',
#  'ON27IN1_output_1FN_done_02.csv',
#  'ON27IN1_output_2TN_done_39.csv',
#  'ON27IN1_output_5FW_done_12.csv',
#  'ON27IN1_output_1TN_done_01.csv',
#  'ON27IN1_output_5FS_done_46.csv',
#  'ON27IN1_output_2TS_done_37.csv',
#  'ON27IN1_output_0TS_done_00.csv',
#  'ON27IN1_output_4FW_done_27.csv',
#  'ON27IN1_output_1FW_done_03.csv',
#  'EH08OI1_output_2TS_done_16.csv',
#  'EH08OI1_output_1TN_done_30.csv',
#  'EH08OI1_output_3FW_done_14.csv',
#  'EH08OI1_output_4FW_done_10.csv',
#  'EH08OI1_output_6FN_done_44.csv',
#  'EH08OI1_output_2TN_done_08.csv',
#  'EH08OI1_output_2TW_done_43.csv',
#  'EH08OI1_output_2FW_done_37.csv',
#  'EH08OI1_output_1FW_done_33.csv',
#  'EH08OI1_output_3FN_done_17.csv',
#  'EH08OI1_output_2FS_done_05.csv',
#  'EH08OI1_output_2FN_done_31.csv',
#  'EH08OI1_output_5TN_done_51.csv',
#  'EH08OI1_output_4FN_done_06.csv',
#  'EH08OI1_output_1TW_done_26.csv',
#  'EH08OI1_output_3TS_done_52.csv',
#  'EH08OI1_output_4FS_done_18.csv',
#  'EH08OI1_output_1FN_done_27.csv',
#  'EH08OI1_output_1TS_done_49.csv',
#  'EH08OI1_output_1FS_done_36.csv',
#  'EH08OI1_output_5FS_done_23.csv',
#  'EH08OI1_output_5FN_done_07.csv',
#  'EH08OI1_output_3FS_done_11.csv',
#  'EH08OI1_output_0TS_done_00.csv',
#  'EH08OI1_output_4TW_done_42.csv',
#  'EH08OI1_output_5FW_done_00.csv',
#  'EH08OI1_output_6FW_done_12.csv',
#  'EH08OI1_output_3TN_done_34.csv',
#  'EH08OI1_output_4TN_done_25.csv',
#  'EH08OI1_output_3TW_done_56.csv',
#  'AE07EM1_output_3TN_done_09.csv',
#  'AE07EM1_output_2FS_done_43.csv',
#  'AE07EM1_output_4TW_done_46.csv',
#  'AE07EM1_output_5FW_done_10.csv',
#  'AE07EM1_output_1TN_done_03.csv',
#  'AE07EM1_output_4FN_done_47.csv',
#  'AE07EM1_output_1FW_done_28.csv',
#  'AE07EM1_output_2TS_done_22.csv',
#  'AE07EM1_output_0TS_done_00.csv',
#  'AE07EM1_output_6FS_done_08.csv',
#  'AE07EM1_output_6FN_done_02.csv',
#  'AE07EM1_output_1TW_done_13.csv',
#  'AE07EM1_output_2TN_done_48.csv',
#  'AE07EM1_output_5FS_done_11.csv',
#  'AE07EM1_output_5FN_done_18.csv',
#  'AE07EM1_output_3TW_done_15.csv',
#  'AE07EM1_output_3TS_done_51.csv',
#  'AE07EM1_output_3FN_done_00.csv',
#  'AE07EM1_output_3FS_done_34.csv',
#  'AE07EM1_output_1FS_done_17.csv',
#  'AE07EM1_output_2TW_done_23.csv',
#  'AE07EM1_output_2FN_done_30.csv',
#  'AE07EM1_output_4FS_done_26.csv',
#  'AE07EM1_output_1FN_done_20.csv',
#  'AE07EM1_output_2FW_done_36.csv',
#  'AE07EM1_output_6FW_done_37.csv',
#  'AE07EM1_output_4TS_done_33.csv',
#  'AE07EM1_output_1TS_done_01.csv',
#  'AE07EM1_output_4FW_done_04.csv',
#  'AE07EM1_output_3FW_done_16.csv',
#  'AE07EM1_output_4TN_done_14.csv',
#  'RE25EK_output_2TW_done_03.csv',
#  'RE25EK_output_3TW_done_24.csv',
#  'RE25EK_output_5FS_done_23.csv',
#  'RE25EK_output_2FN_done_16.csv',
#  'RE25EK_output_1FN_done_12.csv',
#  'RE25EK_output_4TW_done_30.csv',
#  'RE25EK_output_6FS_done_20.csv',
#  'RE25EK_output_4FN_done_22.csv',
#  'RE25EK_output_4TN_done_35.csv',
#  'RE25EK_output_0TS_done_00.csv',
#  'RE25EK_output_3TS_done_10.csv',
#  'RE25EK_output_5FW_done_15.csv',
#  'RE25EK_output_3FW_done_18.csv',
#  'RE25EK_output_4TS_done_06.csv',
#  'RE25EK_output_6FW_done_28.csv',
#  'RE25EK_output_3FN_done_44.csv',
#  'RE25EK_output_2FW_done_01.csv',
#  'RE25EK_output_5TN_done_17.csv',
#  'RE25EK_output_1FW_done_21.csv',
#  'RE25EK_output_3TN_done_05.csv',
#  'RE25EK_output_4FS_done_45.csv',
#  'RE25EK_output_2TS_done_29.csv',
#  'RE25EK_output_1TS_done_39.csv',
#  'RE25EK_output_4FW_done_00.csv',
#  'RE25EK_output_2TN_done_33.csv',
#  'RE25EK_output_6FN_done_27.csv',
#  'RE25EK_output_2FS_done_13.csv',
#  'RE25EK_output_3FS_done_31.csv',
#  'RE25EK_output_1TW_done_08.csv',
#  'RE25EK_output_1FS_done_11.csv',
#  'RE25EK_output_1TN_done_41.csv',
#  'RE25EK_output_5FN_done_25.csv',
#  'VE21IR1_output_2TN_done_35.csv',
#  'VE21IR1_output_2FW_done_19.csv',
#  'VE21IR1_output_5TN_done_32.csv',
#  'VE21IR1_output_6FW_done_31.csv',
#  'VE21IR1_output_3TS_done_25.csv',
#  'VE21IR1_output_6TW_done_44.csv',
#  'VE21IR1_output_3TN_done_28.csv',
#  'VE21IR1_output_1TN_done_21.csv',
#  'VE21IR1_output_1TS_done_29.csv',
#  'VE21IR1_output_2TS_done_11.csv',
#  'VE21IR1_output_5FW_done_41.csv',
#  'VE21IR1_output_3FN_done_01.csv',
#  'VE21IR1_output_5FN_done_34.csv',
#  'VE21IR1_output_2FS_done_10.csv',
#  'VE21IR1_output_4FW_done_49.csv',
#  'VE21IR1_output_5FS_done_05.csv',
#  'VE21IR1_output_1FW_done_47.csv',
#  'VE21IR1_output_6TN_done_46.csv',
#  'VE21IR1_output_1FN_done_27.csv',
#  'VE21IR1_output_3FS_done_30.csv',
#  'VE21IR1_output_2FN_done_13.csv',
#  'VE21IR1_output_1FS_done_36.csv',
#  'VE21IR1_output_4TN_done_40.csv',
#  'VE21IR1_output_1TW_done_12.csv',
#  'VE21IR1_output_4FN_done_26.csv',
#  'VE21IR1_output_2TW_done_02.csv',
#  'VE21IR1_output_4TW_done_24.csv',
#  'VE21IR1_output_6FN_done_17.csv',
#  'VE21IR1_output_4FS_done_15.csv',
#  'VE21IR1_output_3TW_done_45.csv',
#  'VE21IR1_output_3FW_done_22.csv',
#  'VE21IR1_output_0TS_done_00.csv',
#  'VE21IR1_output_6FS_done_42.csv',
#  'MO07LN1_output_2TN_done_36.csv',
#  'MO07LN1_output_2FW_done_19.csv',
#  'MO07LN1_output_1TS_done_12.csv',
#  'MO07LN1_output_1FW_done_09.csv',
#  'MO07LN1_output_3TN_done_39.csv',
#  'MO07LN1_output_4FS_done_45.csv',
#  'MO07LN1_output_3FW_done_28.csv',
#  'MO07LN1_output_3TW_done_59.csv',
#  'MO07LN1_output_6FN_done_55.csv',
#  'MO07LN1_output_4TS_done_32.csv',
#  'MO07LN1_output_1TN_done_08.csv',
#  'MO07LN1_output_4FW_done_17.csv',
#  'MO07LN1_output_6FW_done_53.csv',
#  'MO07LN1_output_2FN_done_24.csv',
#  'MO07LN1_output_1FS_done_02.csv',
#  'MO07LN1_output_3FS_done_35.csv',
#  'MO07LN1_output_3TS_done_43.csv',
#  'MO07LN1_output_3FN_done_22.csv',
#  'MO07LN1_output_2TW_done_16.csv',
#  'MO07LN1_output_5FN_done_03.csv',
#  'MO07LN1_output_4FN_done_31.csv',
#  'MO07LN1_output_1TW_done_14.csv',
#  'MO07LN1_output_1FN_done_06.csv',
#  'MO07LN1_output_5FS_done_33.csv',
#  'MO07LN1_output_0TS_done_00.csv',
#  'MO07LN1_output_2FS_done_44.csv',
#  'MO07LN1_output_4TW_done_51.csv',
#  'MO07LN1_output_2TS_done_27.csv',
#  'LL13AE1_output_5FS_done_27.csv',
#  'LL13AE1_output_6TW_done_11.csv',
#  'LL13AE1_output_2FS_done_37.csv',
#  'LL13AE1_output_3FS_done_10.csv',
#  'LL13AE1_output_2FN_done_28.csv',
#  'LL13AE1_output_2TW_done_07.csv',
#  'LL13AE1_output_1FS_done_23.csv',
#  'LL13AE1_output_1FN_done_17.csv',
#  'LL13AE1_output_1TN_done_00.csv',
#  'LL13AE1_output_6FS_done_40.csv',
#  'LL13AE1_output_3FW_done_26.csv',
#  'LL13AE1_output_4TN_done_20.csv',
#  'LL13AE1_output_0TS_done_00.csv',
#  'LL13AE1_output_3TN_done_25.csv',
#  'LL13AE1_output_2TN_done_03.csv',
#  'LL13AE1_output_4TS_done_29.csv',
#  'LL13AE1_output_2TS_done_39.csv',
#  'LL13AE1_output_2FW_done_22.csv',
#  'LL13AE1_output_6TN_done_19.csv',
#  'LL13AE1_output_1TW_done_41.csv',
#  'LL13AE1_output_4FW_done_06.csv',
#  'LL13AE1_output_1TS_done_13.csv',
#  'LL13AE1_output_1FW_done_08.csv',
#  'LL13AE1_output_5FW_done_21.csv',
#  'LL13AE1_output_5TN_done_18.csv',
#  'LL13AE1_output_3TS_done_32.csv',
#  'LL13AE1_output_4FS_done_09.csv',
#  'LL13AE1_output_4FN_done_01.csv',
#  'LL13AE1_output_6FW_done_42.csv',
#  'LL13AE1_output_5FN_done_34.csv',
#  'LL13AE1_output_3FN_done_02.csv',
#  'LL13AE1_output_3TW_done_38.csv',
#  'LL13AE1_output_4TW_done_14.csv',
#  'LL13AE1_output_6FN_done_30.csv',
#  'LL13AE1_output_5TW_done_31.csv',
#  'OL01AC1_output_3TW_done_12.csv',
#  'OL01AC1_output_6FN_done_32.csv',
#  'OL01AC1_output_4TW_done_17.csv',
#  'OL01AC1_output_1FS_done_01.csv',
#  'OL01AC1_output_6FW_done_42.csv',
#  'OL01AC1_output_3FN_done_06.csv',
#  'OL01AC1_output_2TW_done_33.csv',
#  'OL01AC1_output_5TW_done_34.csv',
#  'OL01AC1_output_2TN_done_08.csv',
#  'OL01AC1_output_5TS_done_39.csv',
#  'OL01AC1_output_1TN_done_24.csv',
#  'OL01AC1_output_1TS_done_38.csv',
#  'OL01AC1_output_2FW_done_19.csv',
#  'OL01AC1_output_6TW_done_45.csv',
#  'OL01AC1_output_3TS_done_09.csv',
#  'OL01AC1_output_4TS_done_27.csv',
#  'OL01AC1_output_5TN_done_35.csv',
#  'OL01AC1_output_4FW_done_29.csv',
#  'OL01AC1_output_3TN_done_16.csv',
#  'OL01AC1_output_3FW_done_11.csv',
#  'OL01AC1_output_2TS_done_36.csv',
#  'OL01AC1_output_5FS_done_43.csv',
#  'OL01AC1_output_0TS_done_00.csv',
#  'OL01AC1_output_4TN_done_31.csv',
#  'OL01AC1_output_5FW_done_10.csv',
#  'OL01AC1_output_1FW_done_07.csv',
#  'OL01AC1_output_3FS_done_28.csv',
#  'OL01AC1_output_1TW_done_05.csv',
#  'OL01AC1_output_1FN_done_14.csv',
#  'OL01AC1_output_2FN_done_00.csv',
#  'OL01AC1_output_6FS_done_21.csv',
#  'OL01AC1_output_4FS_done_15.csv',
#  'OL01AC1_output_5FN_done_13.csv',
#  'OL01AC1_output_4FN_done_20.csv',
#  'OL01AC1_output_2FS_done_22.csv',
#  'ZC12VE_output_2TW_done_11.csv',
#  'ZC12VE_output_1FS_done_27.csv',
#  'ZC12VE_output_3FS_done_03.csv',
#  'ZC12VE_output_1TW_done_07.csv',
#  'ZC12VE_output_2FS_done_19.csv',
#  'ZC12VE_output_5FN_done_29.csv',
#  'ZC12VE_output_2FN_done_12.csv',
#  'ZC12VE_output_5FW_done_06.csv',
#  'ZC12VE_output_3TN_done_18.csv',
#  'ZC12VE_output_4TN_done_09.csv',
#  'ZC12VE_output_0TS_done_00.csv',
#  'ZC12VE_output_2TS_done_23.csv',
#  'ZC12VE_output_1FW_done_01.csv',
#  'ZC12VE_output_5FS_done_40.csv',
#  'ZC12VE_output_4TW_done_41.csv',
#  'ZC12VE_output_4FW_done_25.csv',
#  'ZC12VE_output_1TN_done_05.csv',
#  'ZC12VE_output_1TS_done_14.csv',
#  'ZC12VE_output_2TN_done_26.csv',
#  'ZC12VE_output_3FW_done_16.csv',
#  'ZC12VE_output_6FN_done_37.csv',
#  'ZC12VE_output_4FN_done_00.csv',
#  'ZC12VE_output_3TW_done_15.csv',
#  'ZC12VE_output_1FN_done_31.csv',
#  'ZC12VE_output_3TS_done_52.csv',
#  'ZC12VE_output_3FN_done_17.csv',
#  'ZC12VE_output_6FW_done_51.csv',
#  'ZC12VE_output_4FS_done_24.csv',
#  'ZC12VE_output_4TS_done_54.csv',
#  'ZC12VE_output_2FW_done_45.csv',
#  'FR04AN_output_4FS_done_43.csv',
#  'FR04AN_output_3TS_done_22.csv',
#  'FR04AN_output_3FW_done_12.csv',
#  'FR04AN_output_2FW_done_20.csv',
#  'FR04AN_output_3TN_done_29.csv',
#  'FR04AN_output_4TN_done_05.csv',
#  'FR04AN_output_1TN_done_30.csv',
#  'FR04AN_output_6FN_done_23.csv',
#  'FR04AN_output_2TW_done_27.csv',
#  'FR04AN_output_6FS_done_01.csv',
#  'FR04AN_output_1FN_done_21.csv',
#  'FR04AN_output_1FS_done_14.csv',
#  'FR04AN_output_5FS_done_16.csv',
#  'FR04AN_output_4TW_done_03.csv',
#  'FR04AN_output_5FN_done_10.csv',
#  'FR04AN_output_2FS_done_09.csv',
#  'FR04AN_output_3TW_done_18.csv',
#  'FR04AN_output_3FS_done_28.csv',
#  'FR04AN_output_2FN_done_13.csv',
#  'FR04AN_output_1TW_done_11.csv',
#  'FR04AN_output_4FN_done_25.csv',
#  'FR04AN_output_5TS_done_08.csv',
#  'FR04AN_output_1FW_done_06.csv',
#  'FR04AN_output_5FW_done_04.csv',
#  'FR04AN_output_1TS_done_37.csv',
#  'FR04AN_output_3FN_done_40.csv',
#  'FR04AN_output_2TS_done_36.csv',
#  'FR04AN_output_2TN_done_02.csv',
#  'FR04AN_output_0TS_done_00.csv',
#  'FR04AN_output_4TS_done_15.csv',
#  'FR04AN_output_4FW_done_24.csv',
#  'FR04AN_output_6FW_done_07.csv',
#  'RO25EA1_output_5FS_done_56.csv',
#  'RO25EA1_output_0TS_done_00.csv',
#  'RO25EA1_output_4FW_done_25.csv',
#  'RO25EA1_output_5TN_done_14.csv',
#  'RO25EA1_output_3TN_done_35.csv',
#  'RO25EA1_output_1FW_done_04.csv',
#  'RO25EA1_output_1TN_done_03.csv',
#  'RO25EA1_output_5FW_done_39.csv',
#  'RO25EA1_output_4TN_done_24.csv',
#  'RO25EA1_output_3FS_done_15.csv',
#  'RO25EA1_output_6FS_done_36.csv',
#  'RO25EA1_output_6FN_done_16.csv',
#  'RO25EA1_output_1FS_done_26.csv',
#  'RO25EA1_output_1FN_done_07.csv',
#  'RO25EA1_output_2TW_done_23.csv',
#  'RO25EA1_output_3TS_done_55.csv',
#  'RO25EA1_output_1TW_done_09.csv',
#  'RO25EA1_output_4FS_done_37.csv',
#  'RO25EA1_output_2FS_done_28.csv',
#  'RO25EA1_output_2FN_done_08.csv',
#  'RO25EA1_output_3TW_done_01.csv',
#  'RO25EA1_output_2TS_done_02.csv',
#  'RO25EA1_output_2FW_done_19.csv',
#  'RO25EA1_output_4FN_done_58.csv',
#  'RO25EA1_output_4TW_done_49.csv',
#  'RO25EA1_output_3FW_done_38.csv',
#  'RO25EA1_output_1TS_done_00.csv',
#  'RO25EA1_output_3FN_done_59.csv',
#  'RO25EA1_output_2TN_done_27.csv',
#  'RO25EA1_output_5FN_done_47.csv',
#  'TE26EI1_output_3FS_done_24.csv',
#  'TE26EI1_output_3TW_done_15.csv',
#  'TE26EI1_output_6TW_done_23.csv',
#  'TE26EI1_output_5FN_done_09.csv',
#  'TE26EI1_output_5TN_done_44.csv',
#  'TE26EI1_output_1TW_done_31.csv',
#  'TE26EI1_output_3TS_done_45.csv',
#  'TE26EI1_output_6FW_done_22.csv',
#  'TE26EI1_output_4FS_done_42.csv',
#  'TE26EI1_output_4TS_done_26.csv',
#  'TE26EI1_output_2TS_done_03.csv',
#  'TE26EI1_output_4FW_done_38.csv',
#  'TE26EI1_output_6TS_done_28.csv',
#  'TE26EI1_output_1TS_done_04.csv',
#  'TE26EI1_output_4TN_done_18.csv',
#  'TE26EI1_output_4FN_done_40.csv',
#  'TE26EI1_output_3TN_done_08.csv',
#  'TE26EI1_output_1TN_done_17.csv',
#  'TE26EI1_output_0TS_done_00.csv',
#  'TE26EI1_output_1FW_done_00.csv',
#  'TE26EI1_output_5TS_done_32.csv',
#  'TE26EI1_output_2FW_done_07.csv',
#  'TE26EI1_output_1FS_done_41.csv',
#  'TE26EI1_output_2TN_done_29.csv',
#  'TE26EI1_output_5FW_done_02.csv',
#  'TE26EI1_output_6FS_done_37.csv',
#  'TE26EI1_output_1FN_done_13.csv',
#  'TE26EI1_output_3FW_done_46.csv',
#  'TE26EI1_output_5FS_done_33.csv',
#  'TE26EI1_output_2FN_done_01.csv',
#  'TE26EI1_output_4TW_done_35.csv',
#  'TE26EI1_output_3FN_done_36.csv',
#  'TE26EI1_output_2TW_done_16.csv',
#  'TE26EI1_output_6FN_done_10.csv',
#  'TE26EI1_output_2FS_done_27.csv',
#  'OR13UN1_output_5TW_done_19.csv',
#  'OR13UN1_output_5FS_done_01.csv',
#  'OR13UN1_output_2FN_done_30.csv',
#  'OR13UN1_output_3TW_done_29.csv',
#  'OR13UN1_output_2TW_done_33.csv',
#  'OR13UN1_output_4FS_done_37.csv',
#  'OR13UN1_output_3TN_done_13.csv',
#  'OR13UN1_output_4FW_done_10.csv',
#  'OR13UN1_output_6TW_done_43.csv',
#  'OR13UN1_output_2TN_done_20.csv',
#  'OR13UN1_output_1FW_done_36.csv',
#  'OR13UN1_output_3FS_done_41.csv',
#  'OR13UN1_output_6FN_done_42.csv',
#  'OR13UN1_output_5FW_done_24.csv',
#  'OR13UN1_output_6FW_done_09.csv',
#  'OR13UN1_output_6TN_done_31.csv',
#  'OR13UN1_output_3FW_done_38.csv',
#  'OR13UN1_output_3TS_done_23.csv',
#  'OR13UN1_output_2FS_done_44.csv',
#  'OR13UN1_output_0TS_done_00.csv',
#  'OR13UN1_output_4FN_done_50.csv',
#  'OR13UN1_output_4TN_done_18.csv',
#  'OR13UN1_output_4TW_done_46.csv',
#  'OR13UN1_output_1TN_done_16.csv',
#  'OR13UN1_output_2FW_done_17.csv',
#  'OR13UN1_output_5FN_done_02.csv',
#  'OR13UN1_output_1TS_done_47.csv',
#  'OR13UN1_output_3FN_done_34.csv',
#  'OR13UN1_output_2TS_done_40.csv',
#  'OR13UN1_output_1FN_done_15.csv',
#  'OR13UN1_output_1TW_done_07.csv',
#  'OR13UN1_output_1FS_done_32.csv',
#  'EL10RM1_output_2FW_done_51.csv',
#  'EL10RM1_output_3FN_done_14.csv',
#  'EL10RM1_output_3TN_done_58.csv',
#  'EL10RM1_output_2TN_done_56.csv',
#  'EL10RM1_output_4FS_done_24.csv',
#  'EL10RM1_output_6FW_done_45.csv',
#  'EL10RM1_output_5FS_done_28.csv',
#  'EL10RM1_output_5TN_done_50.csv',
#  'EL10RM1_output_5FN_done_18.csv',
#  'EL10RM1_output_1FS_done_04.csv',
#  'EL10RM1_output_2FS_done_03.csv',
#  'EL10RM1_output_1TW_done_34.csv',
#  'EL10RM1_output_1TS_done_10.csv',
#  'EL10RM1_output_4FW_done_05.csv',
#  'EL10RM1_output_1FN_done_46.csv',
#  'EL10RM1_output_3FW_done_11.csv',
#  'EL10RM1_output_2FN_done_40.csv',
#  'EL10RM1_output_3TS_done_37.csv',
#  'EL10RM1_output_2TS_done_21.csv',
#  'EL10RM1_output_1TN_done_12.csv',
#  'EL10RM1_output_0TS_done_00.csv',
#  'EL10RM1_output_5FW_done_01.csv',
#  'EL10RM1_output_4TS_done_00.csv',
#  'EL10RM1_output_1FW_done_06.csv',
#  'EL10RM1_output_3TW_done_20.csv',
#  'EL10RM1_output_3FS_done_07.csv',
#  'EL10RM1_output_4TW_done_25.csv',
#  'EL10RM1_output_2TW_done_13.csv',
#  'EL10RM1_output_4FN_done_35.csv',
#  'LA22KK1_output_1TN_done_25.csv',
#  'LA22KK1_output_1FW_done_23.csv',
#  'LA22KK1_output_3TS_done_27.csv',
#  'LA22KK1_output_5FN_done_41.csv',
#  'LA22KK1_output_3FW_done_03.csv',
#  'LA22KK1_output_5FW_done_35.csv',
#  'LA22KK1_output_4FW_done_16.csv',
#  'LA22KK1_output_6FW_done_37.csv',
#  'LA22KK1_output_2FW_done_22.csv',
#  'LA22KK1_output_1TW_done_42.csv',
#  'LA22KK1_output_2TS_done_04.csv',
#  'LA22KK1_output_4TS_done_26.csv',
#  'LA22KK1_output_3FS_done_21.csv',
#  'LA22KK1_output_6FS_done_39.csv',
#  'LA22KK1_output_5TW_done_32.csv',
#  'LA22KK1_output_2FN_done_09.csv',
#  'LA22KK1_output_1FS_done_11.csv',
#  'LA22KK1_output_4FN_done_30.csv',
#  'LA22KK1_output_4FS_done_38.csv',
#  'LA22KK1_output_3FN_done_34.csv',
#  'LA22KK1_output_2TW_done_13.csv',
#  'LA22KK1_output_2FS_done_20.csv',
#  'LA22KK1_output_3TW_done_08.csv',
#  'LA22KK1_output_1FN_done_10.csv',
#  'LA22KK1_output_6FN_done_17.csv',
#  'LA22KK1_output_4TN_done_44.csv',
#  'LA22KK1_output_4TW_done_40.csv',
#  'LA22KK1_output_1TS_done_31.csv',
#  'LA22KK1_output_6TN_done_29.csv',
#  'LA22KK1_output_0TS_done_00.csv',
#  'LA22KK1_output_5FS_done_47.csv',
#  'LA22KK1_output_2TN_done_06.csv',
#  'LA22KK1_output_5TN_done_02.csv',
#  'LA22KK1_output_3TN_done_36.csv',
#  'UD06AD_output_6FW_done_12.csv',
#  'UD06AD_output_6FS_done_44.csv',
#  'UD06AD_output_0TS_done_00.csv',
#  'UD06AD_output_2FW_done_10.csv',
#  'UD06AD_output_1FW_done_15.csv',
#  'UD06AD_output_3TN_done_21.csv',
#  'UD06AD_output_3FW_done_26.csv',
#  'UD06AD_output_1TN_done_00.csv',
#  'UD06AD_output_2TN_done_05.csv',
#  'UD06AD_output_4TS_done_06.csv',
#  'UD06AD_output_4FW_done_46.csv',
#  'UD06AD_output_3FN_done_20.csv',
#  'UD06AD_output_4FN_done_32.csv',
#  'UD06AD_output_6FN_done_04.csv',
#  'UD06AD_output_2TW_done_02.csv',
#  'UD06AD_output_1FS_done_18.csv',
#  'UD06AD_output_4TW_done_24.csv',
#  'UD06AD_output_1FN_done_11.csv',
#  'UD06AD_output_3TW_done_37.csv',
#  'UD06AD_output_4FS_done_28.csv',
#  'UD06AD_output_3FS_done_08.csv',
#  'UD06AD_output_6TW_done_34.csv',
#  'UD06AD_output_1TW_done_25.csv',
#  'UD06AD_output_2TS_done_48.csv',
#  'UD06AD_output_2FN_done_09.csv',
#  'UD06AD_output_2FS_done_03.csv',
#  'UD06AD_output_5FS_done_49.csv',
#  'UD06AD_output_4TN_done_16.csv',
#  'UD06AD_output_1TS_done_13.csv',
#  'UD06AD_output_5FW_done_35.csv',
#  'UD06AD_output_5FN_done_45.csv',
#  'UD06AD_output_3TS_done_23.csv']

# %% [markdown]
# split successfull_runs by _ and get code ([0]) of trial ([-1]; - cut of .csv). Then use this to read eye_tracking data.

# %%
snippets = []

for file_name in successfull_runs:
    temp = file_name.split("_")
    code = temp[0]
    exp_trial = temp[-1]
    exp_trial = exp_trial[:2]  # cut off .csv
    
    snippets.append([code, exp_trial])

# %% [markdown]
# Convert snippets to pandas df

# %%
snippets_df = pd.DataFrame(snippets, columns = ['code', 'trial'])
snippets_df
# Out:
#        code trial
# 0    OK01UE    10
# 1    OK01UE    25
# 2    OK01UE    16
# 3    OK01UE    27
# 4    OK01UE    07
# ..      ...   ...
# 854  UD06AD    16
# 855  UD06AD    13
# 856  UD06AD    35
# 857  UD06AD    45
# 858  UD06AD    23
#
# [859 rows x 2 columns]

# %% [markdown]
# ## Building eye-movement dataframe

# %%
# filter the content for trials in snippets df
eye_data_successfull_runs = pd.DataFrame()

# slow but explicit for loop...
for id_code in np.unique(snippets_df.code):
    successfull_runs = list(snippets_df.loc[snippets_df['code'] == id_code].trial)
    
    path = root_dir + data_dir + str(id_code) + "/eye_data"
    for subdir, dirs, files in os.walk(path):
        for data_file in files:
            if ".csv" in str(data_file):

                temp = str(data_file).split("_")
                # extract features of run from file_name coding
                level = temp[4][0]
                drift = temp[4][1]
                input_noise = temp[4][2]
                exp_trial = temp[-1]
                exp_trial = exp_trial[:2]
                # check for trial number of successfull trials
                #print(exp_trial, successfull_runs)
                if exp_trial in successfull_runs:

                    #f"experimental_data/{id_code}/eye_data/{data_file}"
                    temp_data = pre_process_eye_data(pd.read_csv((f"experimental_data/{id_code}/eye_data/{data_file}"), index_col=False))
                    temp_data["ID"] = id_code
                    temp_data["level"] = level
                    temp_data["drift"] = drift
                    temp_data["input_noise"] = input_noise

                    eye_data_successfull_runs = pd.concat([eye_data_successfull_runs, temp_data])

# %% [markdown]
# 72460872 rows of data generated for final data set.

# %%
def func(x):
    if x == 1:
        return "easy"
    elif x == 2:
        return "easy"
    elif x == 3:
        return "medium"
    elif x == 4:
        return "medium"
    elif x == 5:
        return "hard"
    elif x == 6:
        return "hard"
    else:
        return 'N/A'

#eye_data_successfull_runs["level_difficulty"] = eye_data_successfull_runs.level.apply(func)

# Calling func for the sub data frames for fixations and saccades individually is more efficient (less time consuming).

# %% [markdown]
# ### Extracting fixations

# %%
fix_data = eye_data_successfull_runs[eye_data_successfull_runs.fixationOnset == 1].reset_index()

# %%
N_visible_obs_col = []
N_visible_drift_col = []
Dist_to_closest_obstacle_col = []

for index, row in fix_data.iterrows():
    
    input_file_name = f'{row.ID}_output_{row.level}{str(row.drift)[0]}{row.input_noise}_done_'
    
    path = f'experimental_data/{row.ID}/data/'
    
    file_found = False
    
    for subdir, dirs, files in os.walk(path):
        for data_file in files:
            if input_file_name in str(data_file):
                
                file_found = True
                
                #print(f'searching for {data_file}')
                
                input_data = pre_process_input_data(pd.read_csv(f'{path}/{data_file}', index_col=False))
                
                closest_frame = input_data.iloc[(input_data['time_played'] - row.time_tag).abs().argsort()[0]]
                
                distances = []
                for obstacle in closest_frame.visible_obstacles:
                    dist_squared = np.power(np.abs(obstacle[0] - agent_center_x), 2) + np.power(np.abs(obstacle[1] - agent_center_y), 2)
                    distances.append(np.sqrt(dist_squared))
                
                if len(distances) > 0:
                    Dist_to_closest_obstacle = np.min(distances)
                elif len(distances) == 0:
                    Dist_to_closest_obstacle = np.nan
                    
                N_visible_obstacles = len(closest_frame.visible_obstacles)
                N_visible_drift = len(closest_frame.visible_drift_tiles)
                
                N_visible_obs_col.append(N_visible_obstacles)
                N_visible_drift_col.append(N_visible_drift)
                Dist_to_closest_obstacle_col.append(Dist_to_closest_obstacle)
    
    if not file_found:
        N_visible_obs_col.append(np.nan)
        N_visible_drift_col.append(np.nan)
        Dist_to_closest_obstacle_col.append(np.nan)

# %%
fix_data = fix_data.astype({'level':'int'})

fix_data["level_difficulty"] = fix_data.level.apply(func)

# %%
fix_data.insert (37, 'N_visible_obstacles', N_visible_obs_col)
fix_data.insert (37, 'N_visible_drift_tiles', N_visible_drift_col)
fix_data.insert (37, 'Dist_to_closest_obstacles_in_pixel', Dist_to_closest_obstacle_col)

fix_data['Dist_to_closest_obstacles'] = fix_data.apply(lambda row: pixel_to_degree(row.Dist_to_closest_obstacles_in_pixel), axis=1)

# drop unnecessary columns for fixation data
fix_data = fix_data.drop(labels=["saccade_amplitude", "saccade_amplitude_in_pixel", "saccade_direction_y", "saccade_direction_x", "saccadeOnset", "N_saccade", "Saccade"], axis = 1)

fix_data.to_csv('eye_data/experimental_eye_data_fixations.csv', sep=',')

# %% [markdown]
# ### Extracting saccades

# %%
sacc_data = eye_data_successfull_runs[eye_data_successfull_runs.saccadeOnset == 1].reset_index()

# %%
N_visible_obs_col = []
N_visible_drift_col = []
Dist_to_closest_obstacle_col = []

for index, row in sacc_data.iterrows():
    
    input_file_name = f'{row.ID}_output_{row.level}{str(row.drift)[0]}{row.input_noise}_done_'
    
    path = f'experimental_data/{row.ID}/data/'
    
    file_found = False
    
    for subdir, dirs, files in os.walk(path):
        for data_file in files:
            if input_file_name in str(data_file):
                
                file_found = True
                
                #print(f'searching for {data_file}')
                
                input_data = pre_process_input_data(pd.read_csv(f'{path}/{data_file}', index_col=False))
                
                closest_frame = input_data.iloc[(input_data['time_played'] - row.time_tag).abs().argsort()[0]]
                
                distances = []
                for obstacle in closest_frame.visible_obstacles:
                    dist_squared = np.power(np.abs(obstacle[0] - agent_center_x), 2) + np.power(np.abs(obstacle[1] - agent_center_y), 2)
                    distances.append(np.sqrt(dist_squared))
                
                if len(distances) > 0:
                    Dist_to_closest_obstacle = np.min(distances)
                elif len(distances) == 0:
                    Dist_to_closest_obstacle = np.nan
                    
                N_visible_obstacles = len(closest_frame.visible_obstacles)
                N_visible_drift = len(closest_frame.visible_drift_tiles)
                
                N_visible_obs_col.append(N_visible_obstacles)
                N_visible_drift_col.append(N_visible_drift)
                Dist_to_closest_obstacle_col.append(Dist_to_closest_obstacle)
    
    if not file_found:
        N_visible_obs_col.append(np.nan)
        N_visible_drift_col.append(np.nan)
        Dist_to_closest_obstacle_col.append(np.nan)

# %%
sacc_data = sacc_data.astype({'level':'int'})

sacc_data["level_difficulty"] = sacc_data.level.apply(func)

# %%
sacc_data.insert (37, 'N_visible_obstacles', N_visible_obs_col)
sacc_data.insert (37, 'N_visible_drift_tiles', N_visible_drift_col)
sacc_data.insert (37, 'Dist_to_closest_obstacles_in_pixel', Dist_to_closest_obstacle_col)

sacc_data['Dist_to_closest_obstacles'] = sacc_data.apply(lambda row: pixel_to_degree(row.Dist_to_closest_obstacles_in_pixel), axis=1)

# drop unnecessary columns for fixation data
sacc_data = sacc_data.drop(labels=["fixation_duration", "exploring_fixation", "fixationOnset", "N_fixation", "Fixation"], axis = 1)

sacc_data.to_csv('eye_data/experimental_eye_data_saccades.csv', sep=',')

# %% [markdown]
# ## Building SoC data

# %% [markdown]
# Here we **won't** filter for only successful runs.

# %%
root_dir = os.getcwd()

data_dir = "/experimental_data/"
target_string = "output"

#done_string = "done"
#crashed_string = "crashed"

runs = []

for subdir, dirs, files in os.walk(root_dir+data_dir):
    for file in files:
        runs.append(file)
        
        #if done_string in file:
        #    runs.append(file)
        #if crashed_string in file:
        #    runs.append(file)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 15
#      13 if done_string in file:
#      14     runs.append(file)
# ---> 15 if crashed_string in file:
#      16     runs.append(file)
#
# NameError: name 'crashed_string' is not defined

# %%
snippets_runs = []

for file_name in runs:
    temp = file_name.split("_")
    code = temp[0]
    exp_trial = temp[-1]
    exp_trial = exp_trial[:2]  # cut off .csv
    
    snippets_runs.append([code, exp_trial])

# %%
snippets_runs_df = pd.DataFrame(snippets_runs, columns = ['code', 'trial'])
snippets_runs_df

# %%
#%%capture --no-stderr

soc_data = pd.DataFrame()


for id_code in np.unique(snippets_runs_df.code):
    experimental_runs = list(snippets_runs_df.loc[snippets_runs_df['code'] == id_code].trial)
    
    path = root_dir + data_dir + str(id_code) + "/data"
    for subdir, dirs, files in os.walk(path):
        for data_file in files:
            if ".csv" in str(data_file):
                
                temp = str(data_file).split("_")
                # extract features of run from file_name coding
                level = temp[2][0]
                drift = temp[2][1]
                input_noise = temp[2][2]
                exp_trial = temp[-1]
                exp_trial = exp_trial[:2]
                done = temp[3]
                if int(level) > 0:  # excluding training trials
                
                    # writing to a temporal data frame
                    temp_data = pd.DataFrame({'ID': [np.nan],
                                              'level': [np.nan],
                                              'drift': [np.nan],
                                              'input_noise': [np.nan],
                                              'N_fixations': [np.nan],
                                              'N_distant_fixations': [np.nan],
                                              'N_saccades': [np.nan],
                                              'done': [np.nan],
                                              'run': [np.nan], 
                                              'SoC': [np.nan]})

                    opened_file = pre_process_input_data(pd.read_csv((f"experimental_data/{id_code}/data/{data_file}"), index_col=False))
                    temp_eye_data_file = pre_process_eye_data(pd.read_csv(f"experimental_data/{id_code}/eye_data/{id_code}_eye_tracking_output_{level}{drift}{input_noise}_{exp_trial}.csv"))
                    temp_data["ID"].iloc[0] = id_code
                    temp_data["level"].iloc[0] = level
                    temp_data["drift"].iloc[0] = drift
                    temp_data["input_noise"].iloc[0] = input_noise
                    temp_data["N_fixations"].iloc[0] = np.max(temp_eye_data_file.N_fixation)
                    temp_data["N_distant_fixations"].iloc[0] = np.sum(temp_eye_data_file.exploring_fixation)
                    temp_data["N_saccades"].iloc[0] = np.max(temp_eye_data_file.N_saccade)                                                     
                    if done == "crashed":
                        temp_data["done"].iloc[0] = False
                    elif done == "done":
                        temp_data["done"].iloc[0] = True
                    temp_data["run"].iloc[0] = exp_trial
                    temp_data["SoC"].iloc[0] = opened_file["SoC"].iloc[-1]

                    soc_data = pd.concat([soc_data, temp_data])

soc_data

# %% [markdown]
# ### Adding additional columns

# %%
soc_df = pd.DataFrame()

unique_IDs = soc_data.ID.unique()

for ident in unique_IDs:
    # simultaneously sorting data by run (cronologically)
    temp_df = soc_data[soc_data.ID == ident].sort_values(['run'], ascending=True)
    
    # condition for crash in data
    cond = (temp_df.done == False)

    # have =1 everywhere condition applies and =0 where not
    temp_df["crashed"] = np.where(cond, 1, 0)
    
    # counting up crashs
    temp_df['N_prior_crashs'] = temp_df.crashed.cumsum()
    
    # we will have to subtract 1 from each row where they crashed due to cumsum already updating the crash row. 
    # But we want specifically the PRIOR crashs.
    temp_df.N_prior_crashs = temp_df.N_prior_crashs - temp_df.crashed
    
    soc_df = pd.concat([soc_df, temp_df])
    
soc_df

# %%
soc_df_=soc_df.assign(trials_since_last_crash=soc_df.groupby(soc_df.crashed.ne(soc_df.crashed.shift()).cumsum()).cumcount().add(1))
soc_df_.trials_since_last_crash = soc_df_.trials_since_last_crash - soc_df_.crashed

#test_df = new_soc_df.copy()

cond = (soc_df_.crashed.shift(1) > 0.0)
soc_df_["crashed_in_last_trial"] = np.where(cond, 1, 0)

cond = (soc_df_.crashed.shift(1) > 0.0) & (soc_df_.crashed == 0)
soc_df_["consecutive_crash_success"] = np.where(cond, 1, 0)

soc_df_["N_consecutive_crash_success"] = soc_df_.groupby('ID')["consecutive_crash_success"].cumsum()

soc_df_

# %%
soc_df_.to_csv('soc_data/soc_data.csv', sep=',', index=False)

# %% [markdown]
# ## Building input data
